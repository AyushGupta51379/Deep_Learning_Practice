# %%
import numpy as np
import pandas as pd 
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random
import os

# %% [markdown]
# Define constants

# %%
FAST_RUN = False
IMAGE_WIDTH=128
IMAGE_HEIGHT=128
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
IMAGE_CHANNELS=3

# %% [markdown]
# Prepare data

# %% [markdown]
# Download data and save it

# %%
url = 'https://drive.google.com/file/d/1Bv0NmvbZ0Za9sxF0Zto7wxil_H_qSvnP/view?usp=sharing'

# %%
# !gdown --id 1Bv0NmvbZ0Za9sxF0Zto7wxil_H_qSvnP
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Bv0NmvbZ0Za9sxF0Zto7wxil_H_qSvnP
# To: /content/train.zip
# 570MB [00:11, 47.8MB/s]

# %% [markdown]
# Unzip and save into folder train_extracted

# %%
import zipfile
with zipfile.ZipFile("train.zip","r") as zip_ref:
    zip_ref.extractall("./train_extracted")

# %% [markdown]
# Exract labels from image names and save image names with corresponding labels in dataframe

# %%
filenames = os.listdir("./train_extracted/train")
categories = []
for filename in filenames:
    category = filename.split('.')[0]
    if category == 'dog':
        categories.append(1) # 1 for dog
    else:
        categories.append(0) # 0 for cat

df = pd.DataFrame({
    'filename': filenames,
    'category': categories
})

# %%
df.head()
# Out:
#         filename  category
# 0  cat.10424.jpg         0
# 1   dog.7160.jpg         1
# 2   dog.4033.jpg         1
# 3    dog.353.jpg         1
# 4   cat.2571.jpg         0

# %%
df.tail()
# Out:
#             filename  category
# 24995   cat.6560.jpg         0
# 24996  cat.10230.jpg         0
# 24997   cat.3565.jpg         0
# 24998   cat.5970.jpg         0
# 24999   cat.2937.jpg         0

# %%
df.describe()
# Out:
#           category
# count  25000.00000
# mean       0.50000
# std        0.50001
# min        0.00000
# 25%        0.00000
# 50%        0.50000
# 75%        1.00000
# max        1.00000

# %% [markdown]
# Total count

# %%
label_counts = df.groupby('category').size()
print(label_counts)
# Out:
# category
# 0    12500
# 1    12500
# dtype: int64

# %%
df['category'].value_counts().plot.bar()

# %% [markdown]
# Sample image

# %%
sample = random.choice(filenames)
image = load_img("./train_extracted/train/"+sample)
plt.imshow(image)

# %%
sample = random.choice(filenames)
image = load_img("./train_extracted/train/"+sample)
plt.imshow(image)

# %%
sample = random.choice(filenames)
image = load_img("./train_extracted/train/"+sample)
plt.imshow(image)

# %% [markdown]
# Build Model
#
#
# Input Layer: It represent input image data. It will reshape image into single diminsion array. Example your image is 64x64 = 4096, it will convert to (4096,1) array.
#
# Conv Layer: This layer will extract features from image.
#
# Pooling Layer: This layerreduce the spatial volume of input image after convolution.
#
# Fully Connected Layer: It connect the network from a layer to another layer
#
# Output Layer: It is the predicted values layer.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, IMAGE_CHANNELS)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax')) # 2 because we have cat and dog classes

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 126, 126, 32)      896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 126, 126, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 61, 61, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 61, 61, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 128)       73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 28, 28, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 14, 14, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               12845568
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 12,942,786
# Trainable params: 12,941,314
# Non-trainable params: 1,472
# _________________________________________________________________

# %% [markdown]
# Callbacks

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %% [markdown]
# Early Stop
#
# To prevent over fitting we will stop the learning after 10 epochs and val_loss value not decreased

# %%
earlystop = EarlyStopping(patience=10)

# %% [markdown]
# Learning Rate Reduction
#
# We will reduce the learning rate when then accuracy not increase for 2 steps

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=2, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
callbacks = [earlystop, learning_rate_reduction]

# %% [markdown]
# Shuffle data frame

# %%
# shuffle the DataFrame rows 
df = df.sample(frac = 1).reset_index(drop=True)

# %%
df.head()
# Out:
#        filename  category
# 0   cat.101.jpg         0
# 1  dog.7632.jpg         1
# 2  cat.3157.jpg         0
# 3  cat.9025.jpg         0
# 4  cat.8687.jpg         0

# %%
df.tail()
# Out:
#             filename  category
# 24995   cat.7716.jpg         0
# 24996    cat.837.jpg         0
# 24997   cat.3645.jpg         0
# 24998    dog.120.jpg         1
# 24999  cat.10369.jpg         0

# %%
filenames = []
categories = []
for i in range(0, len(df)):
  filenames.append(str(df['filename'][i]))
  categories.append((df['category'][i]))
print(len(filenames))
print(len(categories))
# Out:
# 25000
# 25000

# %%
print(filenames[0])
print(categories[0])
print(filenames[-1])
print(categories[-1])
# Out:
# cat.101.jpg
# 0
# cat.10369.jpg
# 0

# %% [markdown]
# Prepare data
#
# Because we will use image genaretor with class_mode="categorical". We need to convert column category into string. Then imagenerator will convert it one-hot encoding which is good for our classification.
#
# So we will convert 1 to dog and 0 to cat

# %%
df["category"] = df["category"].replace({0: 'cat', 1: 'dog'})

# %%
df.head()
# Out:
#        filename category
# 0   cat.101.jpg      cat
# 1  dog.7632.jpg      dog
# 2  cat.3157.jpg      cat
# 3  cat.9025.jpg      cat
# 4  cat.8687.jpg      cat

# %%
len(df['category'])
# Out:
# 25000

# %% [markdown]
# Divide into 50% train and 50% test, Note that we have shuffled earlier

# %%
mid = int(len(df)/2)
df_train = df[:mid]
df_test = df[mid:].reset_index(drop=True)
print(len(df_train))
print(len(df_test))
# Out:
# 12500
# 12500

# %%
train_df, validate_df = train_test_split(df_train, test_size=0.20, random_state=42)
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
train_df['category'].value_counts().plot.bar()

# %%
validate_df['category'].value_counts().plot.bar()

# %%
total_train = train_df.shape[0]
total_validate = validate_df.shape[0]
batch_size=15

# %% [markdown]
# Traning Generator

# %%
train_datagen = ImageDataGenerator(
    rotation_range=15,
    rescale=1./255,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
)

train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    "./train_extracted/train/", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 10000 validated image filenames belonging to 2 classes.

# %% [markdown]
# Validation Generator

# %%
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    "./train_extracted/train/", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 2500 validated image filenames belonging to 2 classes.

# %% [markdown]
# See how our generator work

# %%
example_df = train_df.sample(n=1).reset_index(drop=True)
example_generator = train_datagen.flow_from_dataframe(
    example_df, 
    "./train_extracted/train/", 
    x_col='filename',
    y_col='category',
    target_size=IMAGE_SIZE,
    class_mode='categorical'
)
# Out:
# Found 1 validated image filenames belonging to 1 classes.

# %%
plt.figure(figsize=(12, 12))
for i in range(0, 15):
    plt.subplot(5, 3, i+1)
    for X_batch, Y_batch in example_generator:
        image = X_batch[0]
        plt.imshow(image)
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# Seems great

# %% [markdown]
# Fit Model

# %%
FAST_RUN = False

# %%
epochs=3 if FAST_RUN else 100
history = model.fit_generator(
    train_generator, 
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=total_validate//batch_size,
    steps_per_epoch=total_train//batch_size,
    callbacks=callbacks
)
# Out:
# WARNING:tensorflow:From <ipython-input-38-9f01d695ce4a>:8: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/100
# 666/666 [==============================] - 86s 129ms/step - loss: 0.8420 - accuracy: 0.6011 - val_loss: 0.5861 - val_accuracy: 0.7044
# Epoch 2/100
# 666/666 [==============================] - 86s 130ms/step - loss: 0.5972 - accuracy: 0.6932 - val_loss: 0.6451 - val_accuracy: 0.6964
# Epoch 3/100
# 666/666 [==============================] - ETA: 0s - loss: 0.5611 - accuracy: 0.7195
# Epoch 00003: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 666/666 [==============================] - 86s 129ms/step - loss: 0.5611 - accuracy: 0.7195 - val_loss: 0.8427 - val_accuracy: 0.6594
# Epoch 4/100
# 666/666 [==============================] - 86s 130ms/step - loss: 0.4919 - accuracy: 0.7579 - val_loss: 0.4622 - val_accuracy: 0.7799
# Epoch 5/100
# 666/666 [==============================] - 86s 129ms/step - loss: 0.4605 - accuracy: 0.7846 - val_loss: 0.4580 - val_accuracy: 0.7980
# Epoch 6/100
# 666/666 [==============================] - 87s 130ms/step - loss: 0.4506 - accuracy: 0.7921 - val_loss: 0.4320 - val_accuracy: 0.8100
# Epoch 7/100
# 666/666 [==============================] - 86s 128ms/step - loss: 0.4318 - accuracy: 0.7983 - val_loss: 0.7982 - val_accuracy: 0.7442
# Epoch 8/100
# 666/666 [==============================] - 86s 128ms/step - loss: 0.4297 - accuracy: 0.8011 - val_loss: 0.4029 - val_accuracy: 0.8273
# Epoch 9/100
# 666/666 [==============================] - 87s 130ms/step - loss: 0.4148 - accuracy: 0.8090 - val_loss: 0.3822 - val_accuracy: 0.8301
# Epoch 10/100
# 666/666 [==============================] - 87s 130ms/step - loss: 0.4079 - accuracy: 0.8112 - val_loss: 0.4885 - val_accuracy: 0.7932
# Epoch 11/100
# 666/666 [==============================] - ETA: 0s - loss: 0.4014 - accuracy: 0.8128
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 666/666 [==============================] - 86s 130ms/step - loss: 0.4014 - accuracy: 0.8128 - val_loss: 0.4641 - val_accuracy: 0.7964
# Epoch 12/100
# 666/666 [==============================] - 87s 130ms/step - loss: 0.3762 - accuracy: 0.8302 - val_loss: 0.3572 - val_accuracy: 0.8542
# Epoch 13/100
# 666/666 [==============================] - 87s 131ms/step - loss: 0.3592 - accuracy: 0.8443 - val_loss: 0.3560 - val_accuracy: 0.8606
# Epoch 14/100
# 666/666 [==============================] - 87s 130ms/step - loss: 0.3548 - accuracy: 0.8433 - val_loss: 0.3813 - val_accuracy: 0.8426
# Epoch 15/100
# 666/666 [==============================] - 87s 130ms/step - loss: 0.3398 - accuracy: 0.8521 - val_loss: 0.3298 - val_accuracy: 0.8743
# Epoch 16/100
# 666/666 [==============================] - 86s 129ms/step - loss: 0.3454 - accuracy: 0.8493 - val_loss: 0.4363 - val_accuracy: 0.8277
# Epoch 17/100
# 666/666 [==============================] - ETA: 0s - loss: 0.3366 - accuracy: 0.8515
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 666/666 [==============================] - 87s 130ms/step - loss: 0.3366 - accuracy: 0.8515 - val_loss: 0.3849 - val_accuracy: 0.8618
# Epoch 18/100
# 666/666 [==============================] - 87s 130ms/step - loss: 0.3342 - accuracy: 0.8532 - val_loss: 0.3485 - val_accuracy: 0.8719
# Epoch 19/100
# 666/666 [==============================] - 87s 130ms/step - loss: 0.3104 - accuracy: 0.8668 - val_loss: 0.3377 - val_accuracy: 0.8791
# Epoch 20/100
# 666/666 [==============================] - 86s 129ms/step - loss: 0.3298 - accuracy: 0.8556 - val_loss: 0.3220 - val_accuracy: 0.8711
# Epoch 21/100
# 666/666 [==============================] - ETA: 0s - loss: 0.3098 - accuracy: 0.8677
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 666/666 [==============================] - 86s 130ms/step - loss: 0.3098 - accuracy: 0.8677 - val_loss: 0.3515 - val_accuracy: 0.8731
# Epoch 22/100
# 666/666 [==============================] - 87s 130ms/step - loss: 0.3100 - accuracy: 0.8644 - val_loss: 0.3310 - val_accuracy: 0.8823
# Epoch 23/100
# 666/666 [==============================] - 87s 130ms/step - loss: 0.3055 - accuracy: 0.8712 - val_loss: 0.2931 - val_accuracy: 0.8916
# Epoch 24/100
# 666/666 [==============================] - 86s 129ms/step - loss: 0.3008 - accuracy: 0.8694 - val_loss: 0.2895 - val_accuracy: 0.8952
# Epoch 25/100
# 666/666 [==============================] - 86s 130ms/step - loss: 0.3008 - accuracy: 0.8760 - val_loss: 0.3310 - val_accuracy: 0.8771
# Epoch 26/100
# 666/666 [==============================] - ETA: 0s - loss: 0.3060 - accuracy: 0.8712
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 666/666 [==============================] - 86s 129ms/step - loss: 0.3060 - accuracy: 0.8712 - val_loss: 0.3362 - val_accuracy: 0.8807
# Epoch 27/100
# 666/666 [==============================] - 86s 129ms/step - loss: 0.2992 - accuracy: 0.8744 - val_loss: 0.3043 - val_accuracy: 0.8884
# Epoch 28/100
# 666/666 [==============================] - ETA: 0s - loss: 0.2987 - accuracy: 0.8717
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 666/666 [==============================] - 87s 130ms/step - loss: 0.2987 - accuracy: 0.8717 - val_loss: 0.3077 - val_accuracy: 0.8904
# Epoch 29/100
# 666/666 [==============================] - 86s 130ms/step - loss: 0.2918 - accuracy: 0.8748 - val_loss: 0.3198 - val_accuracy: 0.8839
# Epoch 30/100
# 666/666 [==============================] - ETA: 0s - loss: 0.2921 - accuracy: 0.8733
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1e-05.
# 666/666 [==============================] - 86s 129ms/step - loss: 0.2921 - accuracy: 0.8733 - val_loss: 0.3012 - val_accuracy: 0.8904
# Epoch 31/100
# 666/666 [==============================] - 86s 129ms/step - loss: 0.2965 - accuracy: 0.8737 - val_loss: 0.3123 - val_accuracy: 0.8908
# Epoch 32/100
# 666/666 [==============================] - 87s 131ms/step - loss: 0.3023 - accuracy: 0.8715 - val_loss: 0.3050 - val_accuracy: 0.8916
# Epoch 33/100
# 666/666 [==============================] - 87s 130ms/step - loss: 0.2896 - accuracy: 0.8775 - val_loss: 0.3072 - val_accuracy: 0.8904
# Epoch 34/100
# 666/666 [==============================] - 87s 131ms/step - loss: 0.2927 - accuracy: 0.8757 - val_loss: 0.3047 - val_accuracy: 0.8932

# %% [markdown]
# Save Model

# %%
model.save_weights("model.h5")

# %%
model.save_weights("Dogs_cats_50epochs_model.h5")

# %%
from google.colab import files
files.download('Dogs_cats_50epochs_model.h5')

# %%
# saving the dataframe 
df.to_csv('df_CatsDogs.csv')
# saving the dataframe 
df_train.to_csv('df_train_CatsDogs.csv')
# saving the dataframe 
df_test.to_csv('df_test_CatsDogs.csv')

# %%
files.download('df_CatsDogs.csv') 
files.download('df_train_CatsDogs.csv') 
files.download('df_test_CatsDogs.csv')

# %%
model.load_weights("model.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %% [markdown]
# Visualize Training

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 12))
ax1.plot(history.history['loss'], color='b', label="Training loss")
ax1.plot(history.history['val_loss'], color='r', label="validation loss")
ax1.set_xticks(np.arange(1, epochs, 1))
ax1.set_yticks(np.arange(0, 1, 0.1))

ax2.plot(history.history['accuracy'], color='b', label="Training accuracy")
ax2.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
ax2.set_xticks(np.arange(1, epochs, 1))

legend = plt.legend(loc='best', shadow=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Prepare Testing Data

# %%
df_test.head()
# Out:
#         filename category
# 0   dog.6308.jpg      dog
# 1   cat.5760.jpg      cat
# 2     dog.36.jpg      dog
# 3  dog.10633.jpg      dog
# 4   dog.5344.jpg      dog

# %%
test_filenames = []
test_categories = []
for i in range(0,len(df_test)):
  test_filenames.append(df_test['filename'][i])
  test_categories.append(df_test['category'][i])
print(len(test_filenames))
# Out:
# 12500

# %%
test_df = df_test
nb_samples = test_df.shape[0]

# %% [markdown]
# Create Testing Generator

# %%
test_gen = ImageDataGenerator(rescale=1./255)
test_generator = test_gen.flow_from_dataframe(
    test_df, 
    "./train_extracted/train/", 
    x_col='filename',
    y_col=None,
    class_mode=None,
    target_size=IMAGE_SIZE,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 12500 validated image filenames.

# %% [markdown]
# Predict

# %%
predict = model.predict(test_generator, steps=np.ceil(nb_samples/batch_size))

# %%
print(predict)
# Out:
# [[0.03728531 0.96271473]
#  [0.883575   0.11642506]
#  [0.36422032 0.6357797 ]
#  ...
#  [0.9796524  0.02034753]
#  [0.13872911 0.8612709 ]
#  [0.986489   0.01351103]]

# %% [markdown]
# For categoral classication the prediction will come with probability of each category. So we will pick the category that have the highest probability with numpy average max

# %%
test_df['category_predicted'] = np.argmax(predict, axis=-1)

# %% [markdown]
# We will convert the predict category back into our generator classes by using train_generator.class_indices. It is the classes that image generator map while converting data into computer vision

# %%
label_map = dict((v,k) for k,v in train_generator.class_indices.items())
test_df['category_predicted'] = test_df['category_predicted'].replace(label_map)

# %% [markdown]
# From our prepare data part. We map data with {1: 'dog', 0: 'cat'}. Now we will map the result back to dog is 1 and cat is 0

# %%
test_df.head()
# Out:
#         filename category category_predicted
# 0   dog.6308.jpg      dog                dog
# 1   cat.5760.jpg      cat                cat
# 2     dog.36.jpg      dog                dog
# 3  dog.10633.jpg      dog                dog
# 4   dog.5344.jpg      dog                dog

# %%
test_df['category_predicted'] = test_df['category_predicted'].replace({ 'dog': 1, 'cat': 0 })
test_df['category'] = test_df['category'].replace({ 'dog': 1, 'cat': 0 })

# %% [markdown]
# Virtaulize Result

# %%
test_df['category_predicted'].value_counts().plot.bar()

# %%
test_df['category'].value_counts().plot.bar()

# %%
test_df.head()
# Out:
#         filename  category  category_predicted
# 0   dog.6308.jpg         1                   1
# 1   cat.5760.jpg         0                   0
# 2     dog.36.jpg         1                   1
# 3  dog.10633.jpg         1                   1
# 4   dog.5344.jpg         1                   1

# %%
y_pred = test_df['category_predicted']
y_true = test_df['category']

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_true, y_pred)
# Out:
# 0.88816

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_true, y_pred)
# Out:
# array([[5675,  646],
#        [ 752, 5427]])

# %%
from sklearn.metrics import cohen_kappa_score
print(cohen_kappa_score(y_true, y_pred))
# Out:
# 0.7762480155855838

# %%
from sklearn.metrics import classification_report # for multilabel classification, gives precision, recall, f score, support, more
target_names = ['Cat', 'Dog']
print("Classification Report:\n", classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#          Cat       0.88      0.90      0.89      6321
#          Dog       0.89      0.88      0.89      6179
#
#     accuracy                           0.89     12500
#    macro avg       0.89      0.89      0.89     12500
# weighted avg       0.89      0.89      0.89     12500

# %% [markdown]
# See predicted result with images

# %%
sample_test = test_df.head(18)
sample_test.head()
plt.figure(figsize=(12, 24))
for index, row in sample_test.iterrows():
    filename = row['filename']
    category = row['category']
    category_predicted = row['category_predicted']
    img = load_img("./train_extracted/train/"+filename, target_size=IMAGE_SIZE)
    plt.subplot(6, 3, index+1)
    plt.imshow(img)
    plt.xlabel(filename + '(' + "{}".format(category_predicted) + ')' + '(' + "{}".format(category) + ')' )
plt.tight_layout()
plt.show()

# %%
# saving the dataframe of our results
test_df.to_csv('test_df_Dogs_cats.csv') 
files.download('test_df_Dogs_cats.csv')
